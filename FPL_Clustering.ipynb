# %% [markdown]
# # FPL Player Clustering Analysis
#
# An unsupervised learning workflow to segment Fantasy Premier League players into
# meaningful groups based on their season performance stats.
#
# **Contents**
# 1. [Setup](#1.-Setup)
# 2. [Load Data](#2.-Load-Data)
# 3. [Exploratory Data Analysis](#3.-Exploratory-Data-Analysis)
# 4. [Preprocessing](#4.-Preprocessing)
# 5. [Dimensionality Reduction (PCA)](#5.-Dimensionality-Reduction-(PCA))
# 6. [Choosing the Number of Clusters](#6.-Choosing-the-Number-of-Clusters)
# 7. [K-Means Clustering](#7.-K-Means-Clustering)
# 8. [Hierarchical Clustering](#8.-Hierarchical-Clustering)
# 9. [Cluster Profiling & Interpretation](#9.-Cluster-Profiling-&-Interpretation)

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## 2. Load Data

# %%
df = pd.read_csv("fpl_data.csv")
print("Data shape:", df.shape)
df.head()
# Out:
# Data shape: (476, 13)
#            Player_Name     Club    Position  Goals_Scored  Assists  \
# 0      Alex Runnarsson  Arsenal  Goalkeeper             0        0
# 1  Alexandre Lacazette  Arsenal     Forward            13        3
# 2           Bernd Leno  Arsenal  Goalkeeper             0        0
# 3          Bukayo Saka  Arsenal  Midfielder             5        5
# 4       Calum Chambers  Arsenal    Defender             0        3
#
#    Total_Points  Minutes  Goals_Conceded  Creativity  Influence  Threat  \
# 0             1       15               0         0.0       16.6       0
# 1           129     1916              21       307.4      602.4     797
# 2           131     3131              37         0.0      702.2       2
# 3           114     2554              31       650.6      493.0     984
# 4            36      751              10       169.4      171.8      77
#
#    Bonus  Clean_Sheets
# 0      0             0
# 1     21             7
# 2     11            11
# ...

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player_Name     476 non-null    str
#  1   Club            476 non-null    str
#  2   Position        476 non-null    str
#  3   Goals_Scored    476 non-null    int64
#  4   Assists         476 non-null    int64
#  5   Total_Points    476 non-null    int64
#  6   Minutes         476 non-null    int64
#  7   Goals_Conceded  476 non-null    int64
#  8   Creativity      476 non-null    float64
#  9   Influence       476 non-null    float64
#  10  Threat          476 non-null    int64
#  11  Bonus           476 non-null    int64
#  12  Clean_Sheets    476 non-null    int64
# dtypes: float64(2), int64(8), str(3)
# memory usage: 48.5 KB

# %%
df.describe().T
# Out:
#                 count         mean          std  min     25%      50%  \
# Goals_Scored    476.0     1.907563     3.455562  0.0    0.00     0.50
# Assists         476.0     1.752101     2.708563  0.0    0.00     0.00
# Total_Points    476.0    58.516807    51.293559  0.0   10.00    48.00
# Minutes         476.0  1336.909664  1073.773995  0.0  268.75  1269.50
# Goals_Conceded  476.0    19.157563    15.946171  0.0    4.00    18.00
# Creativity      476.0   195.976050   251.478541  0.0    8.30    96.95
# Influence       476.0   294.617647   267.779681  0.0   46.50   233.10
# Threat          476.0   224.962185   318.240377  0.0    5.75   104.50
# Bonus           476.0     4.718487     6.252625  0.0    0.00     2.00
# Clean_Sheets    476.0     4.745798     4.394312  0.0    0.00     4.00
#
#                     75%     max
# Goals_Scored       2.00    23.0
# Assists            2.00    14.0
# Total_Points      94.25   244.0
# Minutes         2256.25  3420.0
# ...

# %% [markdown]
# Check for duplicate rows:

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 4. Preprocessing
# Scale the numeric features so no single metric dominates distance-based clustering.

# %%
scaler = StandardScaler()
subset = df.iloc[:, 3:].copy()  # Data with numerical features
subset_scaled = scaler.fit_transform(subset)
data = pd.DataFrame(subset_scaled, columns = subset.columns)

# %% [markdown]
# ## 5. Dimensionality Reduction (PCA)

# %% [markdown]
# ### 5.1 Explained variance

# %%
n = subset.shape[1]
pca = PCA(n_components = n, random_state = 1)
pca.fit(data)

explained_var = pca.explained_variance_
explained_var_ratio = pca.explained_variance_ratio_
cumulative = np.cumsum(explained_var_ratio)

# %%
ev_df = pd.DataFrame({
    "PC": [f"PC{i+1}" for i in range(len(explained_var_ratio))],
    "ExplainedVariance": explained_var,
    "ExplainedVarianceRatio": explained_var_ratio,
    "CumulativeVarianceRatio": cumulative
})
pd.set_option("display.float_format", lambda x: f"{x:.4f}")
print(ev_df)

plt.figure(figsize=(8, 4))
plt.plot(range(1, len(cumulative)+1), cumulative, marker="o")
plt.xlabel("Number of components")
plt.ylabel("Cumulative explained variance")
plt.axhline(0.90, color="r", linestyle="--", linewidth=1)  # 90% guideline
plt.title("Cumulative explained variance")
plt.grid(True)
plt.show()
# Out:
#      PC  ExplainedVariance  ExplainedVarianceRatio  CumulativeVarianceRatio
# 0   PC1             7.2301                  0.7215                   0.7215
# 1   PC2             1.3688                  0.1366                   0.8581
# 2   PC3             0.5892                  0.0588                   0.9169
# 3   PC4             0.3145                  0.0314                   0.9483
# 4   PC5             0.2279                  0.0227                   0.9710
# 5   PC6             0.1526                  0.0152                   0.9862
# 6   PC7             0.0702                  0.0070                   0.9932
# 7   PC8             0.0395                  0.0039                   0.9972
# 8   PC9             0.0195                  0.0019                   0.9991
# 9  PC10             0.0087                  0.0009                   1.0000

# %% [markdown]
# The first 3 principal components retain 91.69% of the total variance.

# %% [markdown]
# ### 5.2 Project onto top components

# %%
n_components = 3

pca = PCA(n_components=n_components, random_state=42)
data_pca = pca.fit_transform(data)
print("PCA shape:", data_pca.shape)
# Out:
# PCA shape: (476, 3)

# %% [markdown]
# ## 6. Choosing the Number of Clusters
# Use the elbow method (inertia) and silhouette score, computed on the PCA-reduced data, to pick a value of *k*.

# %%
k_range = range(2, 11)
inertias = []
sil_scores = []

for k in k_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = km.fit_predict(data_pca)
    inertias.append(km.inertia_)
    sil_scores.append(silhouette_score(data_pca, labels))

# Plot inertia (elbow)
plt.figure(figsize=(8,3.5))
plt.plot(k_range, inertias, marker="o")
plt.xlabel("k")
plt.ylabel("Inertia")
plt.title("Elbow method (inertia)")
plt.xticks(k_range)
plt.show()

# Plot silhouette
plt.figure(figsize=(8,3.5))
plt.plot(k_range, sil_scores, marker="o")
plt.xlabel("k")
plt.ylabel("Silhouette score")
plt.title("Silhouette score by k")
plt.xticks(k_range)
plt.show()

# %% [markdown]
# ## 7. K-Means Clustering

# %%
optimal_k = 3

kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
labels = kmeans.fit_predict(data_pca)
df["Cluster"] = labels

# Cluster centers in PCA space and approximate centers back in original feature space
centers_pca = kmeans.cluster_centers_
centers_original_approx = scaler.inverse_transform(pca.inverse_transform(centers_pca))
centers_df = pd.DataFrame(centers_original_approx, columns=data.columns)
print("Approx cluster centers (original feature scale):")
display(centers_df.round(3))
# Out:
# Approx cluster centers (original feature scale):
#    Goals_Scored  Assists  Total_Points   Minutes  Goals_Conceded  Creativity  \
# 0        8.7870   6.8340      142.5250 2492.4590         33.4350    615.2840
# 1        0.3560   0.3720       17.6200  461.8750          7.1190     51.9250
# 2        1.6060   1.8770       87.4870 2200.3670         31.6520    251.1820
#
#    Influence   Threat   Bonus  Clean_Sheets
# 0   663.3900 867.8780 15.5130        9.6300
# 1    78.4770  65.1550  0.6580        1.3550
# 2   476.2690 218.7490  6.6640        7.9380

# %% [markdown]
# ### 7.1 Visualizing the clusters

# %%
# 2D scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x=data_pca[:,0], y=data_pca[:,1], hue=labels, palette="tab10", s=40, legend="full")
plt.scatter(centers_pca[:,0], centers_pca[:,1], c="black", marker="X", s=200, label="centers")
plt.xlabel("PC1"); plt.ylabel("PC2")
plt.title("Clusters in PCA space (PC1 vs PC2)")
plt.legend(title="Cluster")
plt.show()

# 3D plot
if data_pca.shape[1] >= 3:
    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(data_pca[:,0], data_pca[:,1], data_pca[:,2], c=labels, s=30)
    ax.set_xlabel("PC1"); ax.set_ylabel("PC2"); ax.set_zlabel("PC3")
    plt.title("3D PCA cluster plot")
    plt.show()

# %% [markdown]
# ## 8. Hierarchical Clustering
#
# As a complement to K-Means, we run agglomerative (bottom-up) hierarchical
# clustering on the same PCA-reduced features. The dendrogram gives a visual
# sense of how players merge into groups at different distance thresholds,
# and doesn't require pre-specifying *k* the way K-Means does.

# %% [markdown]
# ### 8.1 Dendrogram

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# Ward linkage minimizes within-cluster variance, similar in spirit to KMeans
Z = linkage(data_pca, method="ward")

plt.figure(figsize=(12, 5))
dendrogram(Z, truncate_mode="lastp", p=30, leaf_rotation=90, leaf_font_size=9, show_contracted=True)
plt.axhline(y=Z[-(optimal_k-1), 2], color="r", linestyle="--", linewidth=1,
            label=f"cut for k={optimal_k}")
plt.xlabel("Player clusters (or cluster size)")
plt.ylabel("Ward distance")
plt.title("Hierarchical Clustering Dendrogram")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.2 Cutting the tree with Agglomerative Clustering
# Cut the dendrogram at the same `optimal_k` used for K-Means so the two methods are directly comparable.

# %%
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(n_clusters=optimal_k, linkage="ward")
hier_labels = agg.fit_predict(data_pca)
df["Cluster_Hierarchical"] = hier_labels

hier_sil = silhouette_score(data_pca, hier_labels)
print(f"Hierarchical clustering silhouette score (k={optimal_k}): {hier_sil:.3f}")
print(f"K-Means silhouette score (k={optimal_k}):               {sil_scores[optimal_k - k_range[0]]:.3f}")

print("\nCounts per hierarchical cluster:")
print(pd.Series(hier_labels).value_counts().sort_index())
# Out:
# Hierarchical clustering silhouette score (k=3): 0.500
# K-Means silhouette score (k=3):               0.514
#
# Counts per hierarchical cluster:
# 0     66
# 1    262
# 2    148
# Name: count, dtype: int64

# %% [markdown]
# ### 8.3 Visualizing the hierarchical clusters

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=data_pca[:, 0], y=data_pca[:, 1], hue=hier_labels, palette="tab10", s=40, legend="full")
plt.xlabel("PC1"); plt.ylabel("PC2")
plt.title("Hierarchical Clusters in PCA space (PC1 vs PC2)")
plt.legend(title="Cluster")
plt.show()

# %% [markdown]
# ### 8.4 Agreement with K-Means
# A cross-tabulation shows how closely the two methods agree on player groupings.

# %%
comparison = pd.crosstab(df["Cluster"], df["Cluster_Hierarchical"],
                          rownames=["KMeans"], colnames=["Hierarchical"])
print(comparison)
# Out:
# Hierarchical   0    1    2
# KMeans
# 0             55    0    8
# 1              0  248    0
# 2             11   14  140

# %% [markdown]
# ## 9. Cluster Profiling & Interpretation
# Profiling below uses the K-Means assignments (`df["Cluster"]`) as the primary segmentation.

# %%
# Profiling: counts & descriptive stats on original numeric features
cluster_counts = df["Cluster"].value_counts().sort_index()
cluster_props = (cluster_counts / len(df)).round(3)
print("Counts per cluster:\n", cluster_counts)
print("Proportions:\n", cluster_props)

# Detailed profile: mean/median/std for numeric features by cluster
profile = df.groupby("Cluster")[data.columns].agg(["mean","median","std"]).round(3)
display(profile)

# Top differentiating features per cluster (relative to global mean)
global_mean = df.iloc[:,3:].mean()
cluster_means = df.groupby("Cluster")[data.columns].mean()
delta_pct = ((cluster_means - global_mean) / global_mean.replace(0, np.nan)).fillna(0)
top_features = {c: delta_pct.loc[c].sort_values(ascending=False).head(5).index.tolist()
                for c in delta_pct.index}
print("Top 5 positively different features per cluster (vs global mean):")
for c, feats in top_features.items():
    print(f" Cluster {c}: {feats}")
# Out:
# Counts per cluster:
#  Cluster
# 0     63
# 1    248
# 2    165
# Name: count, dtype: int64
# Proportions:
#  Cluster
# 0   0.1320
# 1   0.5210
# 2   0.3470
# Name: count, dtype: float64
#         Goals_Scored               Assists               Total_Points  \
#                 mean median    std    mean median    std         mean
# Cluster
# 0             8.7300 9.0000 4.8900  6.7620 6.0000 3.3200     142.1110
# 1             0.3470 0.0000 0.7260  0.4030 0.0000 0.7890      17.9480
# 2             1.6480 1.0000 1.7660  1.8670 1.0000 1.9330      87.5760
#
#                            Minutes  ... Influence   Threat                    \
#           median     std      mean  ...       std     mean   median      std
# Cluster                             ...
# 0       135.0000 32.5310 2476.0630  ...  187.1280 850.6510 814.0000 395.2640
# 1        11.5000 17.7800  455.8510  ...   85.5830  59.1530  15.0000  89.3270
# ...

# %% [markdown]
# * **Cluster 0: The Attacking Dynamo**
#     * **Description:** Players defined by offensive metrics like goals, assists, threat, and creativity.
#     * **Player Type:** Forwards and attacking midfielders.
#
# * **Cluster 1: The Workhorse Defender**
#     * **Description:** Players with high total points and minutes, but also a mixed defensive record (high clean sheets and goals conceded).
#     * **Player Type:** Starting defenders and goalkeepers.
#
# * **Cluster 2: The Influential Defender**
#     * **Description:** Players with high defensive influence, in addition to consistent playing time and defensive stats.
#     * **Player Type:** Central defenders and full-backs.
